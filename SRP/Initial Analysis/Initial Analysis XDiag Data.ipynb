# %% [markdown]
# # Analysis of tblXDiagResults
#
# This notebook contains codes and functions to run queries to analyze the data present in the table `xspoc.xdiagresults` in the `oasis-dev` Database.

# %%
"""
For setting up local imports in an Ipython Shell
This is a workaround for ipython, dont need it for basic python scripts
"""
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import struct
import matplotlib.pyplot as plt

# Project Library
from library.lib_aws import PostgresRDS

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Queries
#
# Uee the `run_query` functions to run queries. Check `Analysis.md` for some examples.

# %%
database = 'oasis-dev'
#table = 'xspoc.xdiagresults'

# %% [markdown]
# ## xdiagresults

# %%
query = """SELECT DISTINCT "NodeID" from xspoc.xdiagresults ORDER BY "NodeID";"""  # Unique well names in the data

cols_query = """
SELECT attname            AS col
     , atttypid::regtype  AS datatype
       -- more attributes?
FROM   pg_attribute
WHERE  attrelid = 'xspoc.xdiagresults'::regclass  -- table name, optionally schema-qualified
AND    attnum > 0
AND    NOT attisdropped
ORDER  BY attnum;
"""

with PostgresRDS(db=database) as engine:  
    well_list_full = pd.read_sql(query, engine)
    col_list_full = pd.read_sql(cols_query, engine)
# Out:
# Connected to oasis-dev DataBase
# Connection Closed

# %%
print("List of Columns")
display(col_list_full)

print('\nList of wells')
display(well_list_full)
# Out:
# List of Columns
#                                      col                     datatype
# 0                                 NodeID                         text
# 1                                   Date  timestamp without time zone
# 2                              PumpCond1                         text
# 3                              PumpCond2                         text
# 4                             FillagePct                       bigint
# 5                                NetProd             double precision
# 6                        FluidLevelXDiag             double precision
# 7                          ElecCostPerBO             double precision
# 8                 ElecCostMinTorquePerBO             double precision
# 9                ElectCostMinEnergyPerBO             double precision
# 10                            PumpEffPct                       bigint
# 11                          SystemEffPct             double precision
# 12                            PumpStroke                       bigint
# 13                        GearBoxLoadPct                       bigint
# 14                    MinTorqueGBLoadPct                       bigint
# 15                    MinEnergyGBLoadPct             double precision
# 16                           BalanceUnit                      boolean
# 17                        TubingPressure                       bigint
# 18                        CasingPressure                       bigint
# 19                             GrossProd                       bigint
# 20                           WaterCutPct                       bigint
# 21                                 MinHP                       bigint
# 22                          PeakGBTorque                       bigint
# 23                           MinGBTorque                       bigint
# 24                       MinEnerGBTorque             double precision
# 25                       MonthlyElecCost                         text
# 26                    MinMonthlyElecCost             double precision
# 27                         ElecCostPerBG             double precision
# 28                      MinElecCostPerBG             double precision
# 29                              PumpSize             double precision
# 30                            TubingLeak                      boolean
# 31                                 BadSG                      boolean
# 32                      AddOilProduction                       bigint
# 33                          AnalysisDate  timestamp without time zone
# 34                                  PPRL             double precision
# 35                                  MPRL             double precision
# 36                         BouyRodWeight             double precision
# 37                              PolRodHP             double precision
# 38                        UnitStructLoad             double precision
# 39                            MaxRodLoad             double precision
# 40                          MinEnergyCLF             double precision
# 41                          MinTorqueCLF             double precision
# 42                            CurrentCLF             double precision
# 43                          MinEnergyMCB             double precision
# 44                          MinTorqueMCB             double precision
# 45                            CurrentMCB             double precision
# 46                          MinEnergyCBE             double precision
# 47                          MinTorqueCBE             double precision
# 48                            CurrentCBE             double precision
# 49                          MinEnergyKWH             double precision
# 50                          MinTorqueKWH             double precision
# 51                            CurrentKWH             double precision
# 52                  MinEnergyMonthlyElec             double precision
# 53                  MinTorqueMonthlyElec             double precision
# 54                    CurrentMonthlyElec             double precision
# 55                       MinEnergyElecBG             double precision
# 56                       MinTorqueElecBG             double precision
# 57                         CurrentElecBG             double precision
# 58                       MinEnergyElecBO                         text
# 59                       MinTorqueElecBO                         text
# 60                         CurrentElecBO                         text
# 61                        TubingMovement             double precision
# 62                       FluidLoadonPump             double precision
# 63                    PumpIntakePressure             double precision
# 64                             LoadShift             double precision
# 65                               WaterSG             double precision
# 66                         OilAPIGravity             double precision
# 67                               FluidSG             double precision
# 68                       GrossPumpStroke             double precision
# 69                      DownholeAnalysis                         text
# 70                           RodAnalysis                         text
# 71                       SurfaceAnalysis                         text
# 72                         InputAnalysis                         text
# 73                 GrossPumpDisplacement             double precision
# 74                     NetStrokeApparent             double precision
# 75                           AvgDHDSLoad                         text
# 76                           AvgDHUSLoad                         text
# 77                         AvgDHDSPOLoad                         text
# 78                         AvgDHUSPOLoad                         text
# 79                          DryRodWeight             double precision
# 80                          PumpFriction             double precision
# 81                           POFluidLoad             double precision
# 82                        PumpEfficiency             double precision
# 83                              CardType                         text
# 84                DownholeAnalysisLocale                         text
# 85                     RodAnalysisLocale                         text
# 86                 SurfaceAnalysisLocale                         text
# 87                   InputAnalysisLocale                         text
# 88                         PumpCondition                         text
# 89                       ElecCostMonthly             double precision
# 90                   GearboxTorqueRating                       bigint
# 91                              Friction             double precision
# 92                             MotorLoad             double precision
# 93                    DownholeCapacity24             double precision
# 94               DownholeCapacityRuntime             double precision
# 95        DownholeCapacityRuntimeFillage             double precision
# 96                      AdditionalUplift                         text
# 97  UpliftCalculationMissingRequirements                         text
# 98                 AdditionalUpliftGross                         text
# List of wells
#                              NodeID
# 0                      Bonner 9-12H
# 1                    Bonner 9X-12HA
# 2                    Bonner 9X-12HB
# 3                      Cade 12-19HA
# 4                      Cade 12-19HB
# 5                      Cade 12X-19H
# 6                     Cook 12-13 6B
# 7                     Cook 12-13 7T
# 8                     Cook 12-13 9T
# 9                    Cook 41-12 11T
# 10   Hanover Federal 5300 41-11 10B
# 11   Hanover Federal 5300 41-11 11T
# 12   Hanover Federal 5300 41-11 12B
# 13  Hanover Federal 5300 41-11 13TX
# 14          Helling Trust 43-22 10T
# 15         Helling Trust 43-22 16T3
# 16           Helling Trust 43-22 4B
# 17           Helling Trust 44-22 5B
# 18           Helling Trust 44-22 6B
# 19           Helling Trust 44-22 7B
# 20          Johnsrud 5198 14-18 11T
# 21          Johnsrud 5198 14-18 13T
# 22         Johnsrud 5198 14-18 15TX
# 23               Lite 5393 31-11 9B
# 24              Lite 5393 41-11 11B
# 25              Lite 5393 41-11 12T
# 26          Rolfson N 5198 12-17 5T
# 27          Rolfson N 5198 12-17 7T
# 28         Rolfson S 5198 11-29 2TX
# 29          Rolfson S 5198 11-29 4T
# 30          Rolfson S 5198 12-29 6T
# 31          Rolfson S 5198 12-29 8T
# 32         Rolfson S 5198 14-29 11T
# 33         Rolfson S 5198 14-29 13T
# 34          Spratley 5494 14-13 12B
# 35          Spratley 5494 14-13 13T
# 36          Spratley 5494 14-13 15T
# 37                  Stenehjem 14-9H
# 38                Stenehjem 14X-9HA
# 39                Stenehjem 14X-9HB
# 40                 Stenehjem 15-9HA
# 41                 Stenehjem 15-9HB
# 42                 Stenehjem 15X-9H

# %% [markdown]
# ## Exploring
#
# Select either the well specific query or the well list query to get the appropriate data. Specify the columns as needed.

# %%
# Add columns within the query itself
# Select only one of the query section below, and comment the other

# WELL SPECIFIC QUERY
well_name = 'Bonner 9-12H'

query = """
SELECT
"NodeID",
"Date",
"TubingPressure",
"CasingPressure",
"PPRL",
"MPRL",
"GrossProd",
"NetProd"
FROM xspoc.xdiagresults
WHERE "NodeID" = '{}'
ORDER BY "Date"
""".format(well_name)

# # WELL LIST QUERY
# well_list = [
#     'Bonner 9-12H',
#     'Bonner 9X-12HA',
#     'Bonner 9X-12HB' 
# ]
# query = """
# SELECT
# "NodeID",
# "Date",
# "TubingPressure",
# "CasingPressure",
# "PPRL",
# "MPRL"
# FROM xspoc.xdiagresults
# WHERE "NodeID" in {}
# ORDER BY "Date"
# """.format(tuple(well_list))

# %%
# Connecting to the DB (from the lib_aws.PostgresRDS Class in the folder library)
# Use th help command (or Shift + tab) for documentation
with PostgresRDS(db=database) as engine:  
    data = pd.read_sql(query, engine, parse_dates=['Date'])

display(data.head())

display(data.describe())
# Out:
# Connected to oasis-dev DataBase
# Connection Closed
#          NodeID                Date  TubingPressure  CasingPressure     PPRL  \
# 0  Bonner 9-12H 2019-07-12 09:43:39               0               0      NaN
# 1  Bonner 9-12H 2019-07-12 12:20:58              25              85  33965.0
# 2  Bonner 9-12H 2019-07-12 12:25:28               0               0      NaN
# 3  Bonner 9-12H 2019-07-14 09:06:04              29              90  31905.0
# 4  Bonner 9-12H 2019-07-14 10:59:27              26              84  31680.0
#
#       MPRL  GrossProd  NetProd
# 0      NaN          0      0.0
# 1  17623.0          0    142.0
# 2      NaN          0      0.0
# 3  18588.0         48    171.0
# 4  19194.0         48    151.0
#        TubingPressure  CasingPressure          PPRL          MPRL  \
# count     1805.000000     1805.000000   1695.000000   1695.000000
# mean        73.546814       84.547922  32822.740413  18456.713864
# std         35.110810       30.012794    820.717958    751.768095
# min          0.000000        0.000000  30797.000000  16386.000000
# 25%         45.000000       75.000000  32121.000000  17889.500000
# 50%         84.000000       91.000000  32853.000000  18338.000000
# 75%         99.000000      103.000000  33419.000000  19024.000000
# max        163.000000      148.000000  35074.000000  21314.000000
#
#          GrossProd      NetProd
# count  1805.000000  1801.000000
# mean     83.483102   121.019989
# std      36.702894    48.330708
# min       0.000000     0.000000
# 25%      71.000000    88.000000
# 50%      83.000000   139.000000
# 75%     103.000000   151.000000
# max     193.000000   231.000000

# %%
# FOr plotting and analysis select a well
# For single well queries well_name will not be needed, for well_list, select a well from that list

# well_name = 'Name'  # Only uncomment for well_list type query

well_data = data[data.NodeID == well_name]

# %%
# PLot Kpis
# Col dict is the column name and the color
# Add or subtract columns if need be from the list of columns quried
col_dict = {
    'TubingPressure': 'r',
    'CasingPressure': 'b',
    'PPRL': 'g',
    'MPRL': 'y'
}

# Plotting
fig, ax = plt.subplots(figsize=(25,5))
for col, c in col_dict.items():
    ax.plot(well_data.Date, well_data.loc[:, col], color=c, label=col, alpha=1)

ax.set_xlabel("Date")
ax.set_ylabel("KPI")
ax.legend(loc='best')
plt.show()

# %%
# SELECT THE COLUMN
col = 'PPRL'

"""
Resampling
"""
print("Initial Analysis for column: {}".format(col))
series = well_data.set_index('Date').loc[:,col]  # Get it as a series

print(series.describe())

print("\nPlot")
series.plot(figsize=(25, 5))
plt.show()

print("\nDay Resampled No fill")
series.resample('D').mean().plot(figsize=(25, 5))
plt.show()


# Resampling and Filling it up wiht limits
print("\n3H Resample, ffill with a limit of 1")
series.resample('3H').mean().ffill(limit=1).plot(figsize=(25,5))
plt.show()
# Out:
# Initial Analysis for column: PPRL
# count     1695.000000
# mean     32822.740413
# std        820.717958
# min      30797.000000
# 25%      32121.000000
# 50%      32853.000000
# 75%      33419.000000
# max      35074.000000
# Name: PPRL, dtype: float64
#
# Plot
# Day Resampled No fill
# 3H Resample, ffill with a limit of 1

# %%
"""
Signal Decomposition
Will Have to eliminate nan values and have a constant frequency
"""
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 20, 12

# Using a 12H Freq, can play around with this
# Using ffill() to populate nan values, can also use fillna(0) to populate it with 0s
y = series.resample('12H').mean().ffill().dropna()
y.isnull().sum(axis=0)

decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Unused Codes

# %%
# """
# Get a list of tables in the database being checked
# """
# # Not needed, as we are using xdiagresults for now
# # query = """
# # SELECT table_name
# # FROM information_schema.tables
# # WHERE table_schema = 'xspoc'
# # ORDER BY table_name
# # """

# # with PostgresRDS(db=database) as engine:
# #     tables = pd.read_sql(query, engine)
    
# # display(tables)

# %%
# # Basic
# d2 = data.dropna(axis=1, how='all', thresh=round(data.shape[0] * 0.9))  # Dropping all columns which have 90% Null values
# d2.info()

# %%
# # Check Various Dtypes
# print("Object Datatype columns: \nList of Columns")
# print(d2.select_dtypes(include='object').columns.to_list())
# print('\nDataFrame')
# d2.select_dtypes(include='object').head()

# %%
# print("Bool Datatype columns: \nList of Columns")
# print(d2.select_dtypes(include='bool').columns.to_list())
# print('\nDataFrame')
# d2.select_dtypes(include='bool').head()

# %%
# print("Float Datatype columns: \nList of Columns")
# print(d2.select_dtypes(include='float64').columns.to_list())
# print('\nDataFrame')
# d2.select_dtypes(include='float64').head()
# print("\nDescription")
# d2.select_dtypes(include='float64').describe().T

# %%
# print("Int Datatype columns: \nList of Columns")
# print(d2.select_dtypes(include='int64').columns.to_list())
# print('\nDataFrame')
# d2.select_dtypes(include='int64').head()
# print("\nDescription")
# d2.select_dtypes(include='int64').describe().T
